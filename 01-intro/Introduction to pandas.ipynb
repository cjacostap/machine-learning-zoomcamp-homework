# %% [markdown]
# ## Intro to pandas

# %%
import numpy as np
import pandas as pd

# %%
data = [
    ['Nissan', 'Stanza', 1991, 138, 4, 'MANUAL', 'sedan', 2000],
    ['Hyundai', 'Sonata', 2017, None, 4, 'AUTOMATIC', 'Sedan', 27150],
    ['Lotus', 'Elise', 2010, 218, 4, 'MANUAL', 'convertible', 54990],
    ['GMC', 'Acadia',  2017, 194, 4, 'AUTOMATIC', '4dr SUV', 34450],
    ['Nissan', 'Frontier', 2017, 261, 6, 'MANUAL', 'Pickup', 32340],
]

columns = [
    'Make', 'Model', 'Year', 'Engine HP', 'Engine Cylinders',
    'Transmission Type', 'Vehicle_Style', 'MSRP'
]

# %%
df = pd.DataFrame(data, columns=columns)

# %%
df
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0   Nissan    Stanza  1991      138.0                 4            MANUAL
# 1  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# 2    Lotus     Elise  2010      218.0                 4            MANUAL
# 3      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP
# 0         sedan   2000
# 1         Sedan  27150
# 2   convertible  54990
# 3       4dr SUV  34450
# 4        Pickup  32340

# %% [markdown]
# ## Series

# %%
df.Make
# Out:
# 0     Nissan
# 1    Hyundai
# 2      Lotus
# 3        GMC
# 4     Nissan
# Name: Make, dtype: object

# %%
df['Make']
# Out:
# 0     Nissan
# 1    Hyundai
# 2      Lotus
# 3        GMC
# 4     Nissan
# Name: Make, dtype: object

# %%
df['id'] = [10, 20, 30, 40, 50]

# %%
df
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0   Nissan    Stanza  1991      138.0                 4            MANUAL
# 1  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# 2    Lotus     Elise  2010      218.0                 4            MANUAL
# 3      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP  id
# 0         sedan   2000  10
# 1         Sedan  27150  20
# 2   convertible  54990  30
# 3       4dr SUV  34450  40
# 4        Pickup  32340  50

# %%
del df['id'] # borrar columna del dataframe

# %%
df
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0   Nissan    Stanza  1991      138.0                 4            MANUAL
# 1  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# 2    Lotus     Elise  2010      218.0                 4            MANUAL
# 3      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP
# 0         sedan   2000
# 1         Sedan  27150
# 2   convertible  54990
# 3       4dr SUV  34450
# 4        Pickup  32340

# %% [markdown]
# ## Index

# %%
df.Make.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df.loc[1] # return row with index 1
# Out:
# Make                   Hyundai
# Model                   Sonata
# Year                      2017
# Engine HP                  NaN
# Engine Cylinders             4
# Transmission Type    AUTOMATIC
# Vehicle_Style            Sedan
# MSRP                     27150
# Name: 1, dtype: object

# %%
df.loc[[1, 2]] # multiple rows
# Out:
#       Make   Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 1  Hyundai  Sonata  2017        NaN                 4         AUTOMATIC
# 2    Lotus   Elise  2010      218.0                 4            MANUAL
#
#   Vehicle_Style   MSRP
# 1         Sedan  27150
# 2   convertible  54990

# %%
df.index = ['a', 'b', 'c', 'd', 'e']

# %%
df.loc[['b','c']]
# Out:
#       Make   Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# b  Hyundai  Sonata  2017        NaN                 4         AUTOMATIC
# c    Lotus   Elise  2010      218.0                 4            MANUAL
#
#   Vehicle_Style   MSRP
# b         Sedan  27150
# c   convertible  54990

# %%
df.iloc[[1,2]] # position index: aumque el indice cambió de numero a letras, con iloc es posible seguir usando la posición de la fila
# loc es para usar el nombre del indice
# iloc es para usar la posición del indice
# Out:
#       Make   Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# b  Hyundai  Sonata  2017        NaN                 4         AUTOMATIC
# c    Lotus   Elise  2010      218.0                 4            MANUAL
#
#   Vehicle_Style   MSRP
# b         Sedan  27150
# c   convertible  54990

# %%
df.reset_index() # quita el index y lo deja como numerico (original); si había un indice de otro tipo genera una nueva columna index
# Out:
#   index     Make     Model  Year  Engine HP  Engine Cylinders  \
# 0     a   Nissan    Stanza  1991      138.0                 4
# 1     b  Hyundai    Sonata  2017        NaN                 4
# 2     c    Lotus     Elise  2010      218.0                 4
# 3     d      GMC    Acadia  2017      194.0                 4
# 4     e   Nissan  Frontier  2017      261.0                 6
#
#   Transmission Type Vehicle_Style   MSRP
# 0            MANUAL         sedan   2000
# 1         AUTOMATIC         Sedan  27150
# 2            MANUAL   convertible  54990
# 3         AUTOMATIC       4dr SUV  34450
# 4            MANUAL        Pickup  32340

# %% [markdown]
# ## String operations

# %%
'Machine Learning zoomcamp'.replace(' ' , '_').lower()
# Out:
# 'machine_learning_zoomcamp'

# %%
df['Vehicle_Style'].str.replace(' ', '_').str.lower()
# Out:
# a          sedan
# b          sedan
# c    convertible
# d        4dr_suv
# e         pickup
# Name: Vehicle_Style, dtype: object

# %%
df['Vehicle_Style'] = df['Vehicle_Style'].str.replace(' ', '_').str.lower()

# %% [markdown]
# ## Summarizing operations

# %%
df.MSRP.min()
# Out:
# np.int64(2000)

# %%
df.MSRP.mean()
# Out:
# np.float64(30186.0)

# %%
df.describe().round(2)
# Out:
#           Year  Engine HP  Engine Cylinders      MSRP
# count     5.00       4.00              5.00      5.00
# mean   2010.40     202.75              4.40  30186.00
# std      11.26      51.30              0.89  18985.04
# min    1991.00     138.00              4.00   2000.00
# 25%    2010.00     180.00              4.00  27150.00
# 50%    2017.00     206.00              4.00  32340.00
# 75%    2017.00     228.75              4.00  34450.00
# max    2017.00     261.00              6.00  54990.00

# %%
df.nunique() #unique values
# Out:
# Make                 4
# Model                5
# Year                 3
# Engine HP            4
# Engine Cylinders     2
# Transmission Type    2
# Vehicle_Style        5
# MSRP                 5
# dtype: int64

# %% [markdown]
# ## Missing values

# %%
df.isnull().sum() # how many missing values have each column?
# Out:
# Make                 0
# Model                0
# Year                 0
# Engine HP            1
# Engine Cylinders     0
# Transmission Type    0
# Vehicle_Style        0
# MSRP                 0
# dtype: int64

# %%
df.groupby('Transmission Type').MSRP.mean()
# Out:
# Transmission Type
# AUTOMATIC    30800.000000
# MANUAL       29776.666667
# Name: MSRP, dtype: float64

# %% [markdown]
# ## Getting the NumPy arrays

# %%
df.MSRP.values
# Out:
# array([ 2000, 27150, 54990, 34450, 32340])

# %%
df.to_dict(orient = 'records') # created a dictionray from the data set
# Out:
# [{'Make': 'Nissan',
#   'Model': 'Stanza',
#   'Year': 1991,
#   'Engine HP': 138.0,
#   'Engine Cylinders': 4,
#   'Transmission Type': 'MANUAL',
#   'Vehicle_Style': 'sedan',
#   'MSRP': 2000},
#  {'Make': 'Hyundai',
#   'Model': 'Sonata',
#   'Year': 2017,
#   'Engine HP': nan,
#   'Engine Cylinders': 4,
#   'Transmission Type': 'AUTOMATIC',
#   'Vehicle_Style': 'Sedan',
#   'MSRP': 27150},
#  {'Make': 'Lotus',
#   'Model': 'Elise',
#   'Year': 2010,
#   'Engine HP': 218.0,
#   'Engine Cylinders': 4,
#   'Transmission Type': 'MANUAL',
#   'Vehicle_Style': 'convertible',
#   'MSRP': 54990},
#  {'Make': 'GMC',
#   'Model': 'Acadia',
#   'Year': 2017,
#   'Engine HP': 194.0,
#   'Engine Cylinders': 4,
#   'Transmission Type': 'AUTOMATIC',
#   'Vehicle_Style': '4dr SUV',
#   'MSRP': 34450},
#  {'Make': 'Nissan',
#   'Model': 'Frontier',
#   'Year': 2017,
#   'Engine HP': 261.0,
#   'Engine Cylinders': 6,
#   'Transmission Type': 'MANUAL',
#   'Vehicle_Style': 'Pickup',
# ...
